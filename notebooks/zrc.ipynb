# %%
import pandas as pd
from ethnicolr import census_ln, pred_census_ln,pred_wiki_ln

# %%
cand_geo = pd.read_csv('../data/cleaned/candidates_surgeo.csv')
# Out:
# C:\Users\samtg\AppData\Local\Temp\ipykernel_11644\1138471954.py:1: DtypeWarning: Columns (12,21,33,37,38,40,41,42,43,44,45,46,51,54) have mixed types. Specify dtype option on import or set low_memory=False.
#   cand_geo = pd.read_csv('../data/cleaned/candidates_surgeo.csv')

# %%
cand_geo.sample(10)
# Out:
#        ELECTION  OFFICECD  RECIPID CANCLASS                 RECIPNAME  \
# 11999      2021        55     2246        P            Joseph, Rita C
# 7804       2021        55     2423        P            Vernikov, Inna
# 7959       2021        55     2308        P             Pierre, Josue
# 10207      2021        55     2377        P  Hollingsworth, Michael D
# 9789       2021        55     2377        P  Hollingsworth, Michael D
# 2989       2021        55     2306        P             Aviles, Alexa
# 7092       2021        55     2332        P        Hantzopoulos, Evie
# 9749       2021        55     2377        P  Hollingsworth, Michael D
# 3956       2021         5     1930        P           Rivera, Carlina
# 8226       2021        55     2308        P             Pierre, Josue
#
#       COMMITTEE  FILING SCHEDULE  PAGENO  SEQUENCENO  ... last_name  zcta5  \
# 11999         H      12      ABC     NaN         NaN  ...    Atkins  11225
# ...

# %%
missing_eth = cand_geo[cand_geo['white'].isna()]

# %%
cand_geo.shape
# Out:
# (16635, 63)

# %%
missing_eth = missing_eth[['RECIPNAME','DATE','REFNO','surname','white','black','api','hispanic','native','multiple']]

# %%
test = census_ln(missing_eth,'surname')

# %%
pred_wiki_ln(missing_eth,'surname')
# Out:
# c:\Users\samtg\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\core\embedding.py:81: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\samtg\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\ops\operation.py:196, in Operation.from_config(cls, config)
#     195 try:
# --> 196     return cls(**config)
#     197 except Exception as e:
#
# File c:\Users\samtg\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\core\embedding.py:81, in Embedding.__init__(self, input_dim, output_dim, embeddings_initializer, embeddings_regularizer, embeddings_constraint, mask_zero, lora_rank, **kwargs)
# ...

# %%
test
# Out:
#           RECIPNAME       DATE     REFNO    surname  white  black  api  \
# 0     Abreu, Adolfo  10/1/2020  R0001855     ABIONA    NaN    NaN  NaN
# 1     Abreu, Adolfo  9/28/2020  R0001736      ABREU    NaN    NaN  NaN
# 2     Abreu, Adolfo  1/11/2021  R0004034     ACOSTA    NaN    NaN  NaN
# 3     Abreu, Adolfo  12/7/2020  R0002655  ACTONBOND    NaN    NaN  NaN
# 4     Abreu, Adolfo   1/8/2021  R0003609      ADLER    NaN    NaN  NaN
# ...             ...        ...       ...        ...    ...    ...  ...
# 3193        Lin, Yu   1/7/2021  R0000305        ZHE    NaN    NaN  NaN
# 3194        Lin, Yu  1/24/2021  R0001102       ZHOU    NaN    NaN  NaN
# 3195        Lin, Yu  2/15/2021  R0001329        ZHU    NaN    NaN  NaN
# 3196        Lin, Yu   1/9/2021  R0000327      ZIANG    NaN    NaN  NaN
# 3197        Lin, Yu  1/11/2021  R0000398        ZOU    NaN    NaN  NaN
#
#       hispanic  native  multiple pctwhite pctblack pctapi pctaian pct2prace  \
# ...

# %%
still_missing = test[test['pctwhite'].isna()]

# %%
still_missing.shape
# Out:
# (1867, 16)

# %% [markdown]
# jobs

# %%
cand_geo.columns
# Out:
# Index(['ELECTION', 'OFFICECD', 'RECIPID', 'CANCLASS', 'RECIPNAME', 'COMMITTEE',
#        'FILING', 'SCHEDULE', 'PAGENO', 'SEQUENCENO', 'REFNO', 'DATE',
#        'REFUNDDATE', 'NAME', 'C_CODE', 'STRNO', 'STRNAME', 'APARTMENT',
#        'BOROUGHCD', 'CITY', 'STATE', 'ZIP', 'OCCUPATION', 'EMPNAME',
#        'EMPSTRNO', 'EMPSTRNAME', 'EMPCITY', 'EMPSTATE', 'AMNT', 'MATCHAMNT',
#        'PREVAMNT', 'PAY_METHOD', 'INTERMNO', 'INTERMNAME', 'INTSTRNO',
#        'INTSTRNM', 'INTAPTNO', 'INTCITY', 'INTST', 'INTZIP', 'INTEMPNAME',
#        'INTEMPSTNO', 'INTEMPSTNM', 'INTEMPCITY', 'INTEMPST', 'INTOCCUPA',
#        'PURPOSECD', 'EXEMPTCD', 'ADJTYPECD', 'RR_IND', 'SEG_IND', 'INT_C_CODE',
#        'first_name', 'last_name', 'zcta5', 'first_name.1', 'surname', 'white',
#        'black', 'api', 'native', 'multiple', 'hispanic'],
#       dtype='object')

# %%
employer = cand_geo['EMPNAME'].value_counts()
employer_df = pd.DataFrame(employer)
employer_df.reset_index(inplace=True)

# %%
employer_df
# Out:
#                              EMPNAME  count
# 0                      Self-Employed   1440
# 1                       Not Employed    540
# 2                            Retired    232
# 3                   City of New York    195
# 4                            NYC DOE    158
# ...                              ...    ...
# 4638  Office of the Attorney General      1
# 4639                     New Visions      1
# 4640              Gettysburg College      1
# 4641         Queens botanical garden      1
# 4642                 Fada Group Inc.      1
#
# [4643 rows x 2 columns]

# %%
job = cand_geo['OCCUPATION'].value_counts()
job_df = pd.DataFrame(job)
job_df.reset_index(inplace=True)

# %%
job_df.head(15)
# Out:
#             OCCUPATION  count
# 0           Unemployed   1344
# 1              Retired   1155
# 2         Not Employed    595
# 3             Attorney    579
# 4              Student    486
# 5              Teacher    418
# 6           Consultant    259
# 7    Software Engineer    255
# 8            Homemaker    191
# 9              Manager    184
# 10            Director    184
# 11              Lawyer    172
# 12           Professor    140
# 13  Executive Director    111
# 14           Physician    104

# %%
from sockit.title import clean, search, sort
import json

# %%
title = 'Software Engineer'

# %%
socs = search(title)

# %%
socs
# Out:
# {}

# %%
print(json.dumps(sort(socs), indent=2))
# Out:
# []
